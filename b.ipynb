# %%
import pandas as pd

# %%
all_info = pd.read_csv('all_info.csv')
all_info
# Out:
#           board                          author category  \
# 0  Bank_Service                 monkkeywom (キラ)       情報
# 1  Bank_Service               calmness26 (一顆蘋果)       情報
# 2  Bank_Service          jackloutter (Clarkson)       新聞
# 3  Bank_Service                   eubrgbf (叢雨廚)       問題
# 4  Bank_Service                     kedine (雀榕)       情報
# 5  Bank_Service  TZUYIC (Je T'aime Celine Dion)       分享
# 6  Bank_Service                  crazyghost ( )       公告
# 7  Bank_Service                    jasome (烏龍奶)       公告
# 8  Bank_Service                   mmokmbdd (雨林)       情報
#
#                         title                      date  \
# 0    星展digibank首登最高領200＋新舊戶抽獎  Thu Feb  1 20:46:29 2024
# 1   中信銀APP連結icashPay新戶最高贈100點  Fri Feb  2 15:55:45 2024
# 2      月初＋農曆年前資料大塞車 郵局系統上午被塞爆  Fri Feb  2 20:27:36 2024
# 3            華南能否線上設定「本人」約定帳號  Fri Feb  2 21:03:50 2024
# 4    永豐DAWHO龍年匯好運 換匯抽日幣、switc  Fri Feb  2 21:11:30 2024
# ...

# %%
all_info.shape
# Out:
# (9, 11)

# %%
all_comments = pd.read_csv('all_comments.csv')
all_comments
# Out:
#     type   commenter                       comment   ipdatetime  source_index  \
# 0      推    yamiyami                  有拿到首次app的100  02/02 01:29             0
# 1      推      skye11           之前有領過了 還是推個～抽獎就碰碰運氣  02/02 13:40             0
# 2      推  autumn0121                         有領過+1  02/02 14:22             0
# 3      推     bigsara       原本看這活動好像到去年底而已，後來又延長到3月  02/02 17:42             0
# 4      推  pippen2002             首次登入app?? 誰還0登入過?  02/02 20:51             0
# ..   ...         ...                           ...          ...           ...
# 454    推    VivianHu       弱弱問一下遠東Bankee推薦碼怎麼找....  02/01 18:30             8
# 455    推     a45321j   這裡不能偷渡推薦碼，直接到FB粉絲團看，或者用理財網紅  02/02 12:36             8
# 456    →     a45321j  的推薦碼都可以，個人覺得五萬額度其實還好重點是1.31%  02/02 12:36             8
# 457    →     a45321j                           無上限  02/02 12:37             8
# 458    推     kentwwx                        請收信，謝謝  02/03 02:20             8
#
#        date_time  ip
# ...
